# %% [markdown]
# ## Dataset overview
# -----------------------
# Source: [Face Verification Using Convolutional Neural Network](https://www.kaggle.com/competitions/11-785-fall-20-homework-2-part-2/data)

# %%
# insert data loading code
